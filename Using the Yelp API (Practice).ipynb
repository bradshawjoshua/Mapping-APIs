# %%
from yelpapi import YelpAPI
import json
import pandas as pd

# %%
with open('C:/Users/joshu/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
pizza_0 = yelp_api.search_query(location='San Diego, CA',
                                       term='Pizza')
type(pizza_0)
pizza_0.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
pizza0 = pd.DataFrame(pizza_0['businesses'])
pizza0.head(2)
# Out:
#                        id                                       alias  \
# 0  vpnHAJ7s9sUBvg8n7yX_2A                       bronx-pizza-san-diego
# 1  Jp8gnq69TqWWvWPwPSEw7Q  rogers-pizzerolo-italian-grill-san-diego-2
#
#                              name  \
# 0                     Bronx Pizza
# 1  Rogers Pizzerolo Italian Grill
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/GKQX9F...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/wp6wRv...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/bronx-pizza-san-diego...          4152
# 1  https://www.yelp.com/biz/rogers-pizzerolo-ital...           105
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'italian', 'title': 'Italian'}, {'a...     5.0
#
# ...

# %%
pizza_0['total']
# Out:
# 2800

# %%
pizza_20 = yelp_api.search_query(location='San Diego, CA',
                                       term='Pizza',
                               offset = 20)

# %%
pizza20 = pd.DataFrame(pizza_20['businesses'])
pizza20.head(2)
# Out:
#                        id                                     alias  \
# 0  Q6N4rqLht_R1k7k-DEY15g                 mr-moto-pizza-san-diego-7
# 1  753amSva2sVGV2RuwmRDQA  tonys-giant-pizzeria-and-grill-san-diego
#
#                             name  \
# 0                  Mr Moto Pizza
# 1  Tony's Giant Pizzeria & Grill
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/HnabwF...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/fb8yi7...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mr-moto-pizza-san-die...           789
# 1  https://www.yelp.com/biz/tonys-giant-pizzeria-...           334
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
# ...

# %%
#now concatenate all pages
all_pizza = pd.concat([pizza0, pizza20],
                      ignore_index=True)
display(all_pizza.head(3), all_pizza.tail(3))
# Out:
#                        id                                       alias  \
# 0  vpnHAJ7s9sUBvg8n7yX_2A                       bronx-pizza-san-diego
# 1  Jp8gnq69TqWWvWPwPSEw7Q  rogers-pizzerolo-italian-grill-san-diego-2
# 2  Kd1aCjEGCreyh9gfcl046Q                the-pizza-standard-san-diego
#
#                              name  \
# 0                     Bronx Pizza
# 1  Rogers Pizzerolo Italian Grill
# 2              The Pizza Standard
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/GKQX9F...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/wp6wRv...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/vCM4SK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/bronx-pizza-san-diego...          4152
# 1  https://www.yelp.com/biz/rogers-pizzerolo-ital...           105
# 2  https://www.yelp.com/biz/the-pizza-standard-sa...           123
#
# ...

# %%
all_pizza.to_json(orient='records')
# Out:
# '[{"id":"vpnHAJ7s9sUBvg8n7yX_2A","alias":"bronx-pizza-san-diego","name":"Bronx Pizza","image_url":"https:\\/\\/s3-media3.fl.yelpcdn.com\\/bphoto\\/GKQX9FYWHAsb22NfjdBL4Q\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/bronx-pizza-san-diego?adjust_creative=Dc2t01QExAh3A9j3FKt7Vg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Dc2t01QExAh3A9j3FKt7Vg","review_count":4152,"categories":[{"alias":"pizza","title":"Pizza"}],"rating":4.5,"coordinates":{"latitude":32.749768,"longitude":-117.1634597},"transactions":["delivery"],"price":"$","location":{"address1":"111 Washington St","address2":"","address3":"","city":"San Diego","zip_code":"92103","country":"US","state":"CA","display_address":["111 Washington St","San Diego, CA 92103"]},"phone":"+16192913341","display_phone":"(619) 291-3341","distance":4620.8284138183},{"id":"Jp8gnq69TqWWvWPwPSEw7Q","alias":"rogers-pizzerolo-italian-grill-san-diego-2","name":"Rogers Pizzerolo Italian Grill","image_url":"h
# ...
